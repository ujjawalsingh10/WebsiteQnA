# %%
url = 'https://pmjay.gov.in/ayushmancapf/resources'

# %%
import re
import hashlib
from urllib.parse import urlparse, urljoin, urlunparse
from typing import Optional

# %%
parsed = urlparse(url.strip())
parsed
# Out:
# ParseResult(scheme='https', netloc='pmjay.gov.in', path='/ayushmancapf/resources', params='', query='', fragment='')

# %%
parsed.port

# %%
parsed.hostname
# Out:
# 'pmjay.gov.in'

# %%
parsed.scheme
# Out:
# 'https'
